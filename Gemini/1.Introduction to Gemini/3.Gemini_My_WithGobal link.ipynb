# %%
#!pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.45.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting anyio<5.0,>=3.0 (from gradio)
#   Using cached anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading Brotli-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.13.0 (from gradio)
#   Downloading gradio_client-1.13.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub<1.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-0.34.6-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (2.3.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (2.3.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (2.11.9)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.13.0-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.17.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec (from gradio-client==1.13.0->gradio)
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.13.0->gradio)
#   Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\anaconda3\envs\envgenai\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Collecting sniffio>=1.1 (from anyio<5.0,>=3.0->gradio)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.47.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: certifi in c:\anaconda3\envs\envgenai\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.33.5->gradio)
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in c:\anaconda3\envs\envgenai\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\anaconda3\envs\envgenai\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda3\envs\envgenai\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\envs\envgenai\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda3\envs\envgenai\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\anaconda3\envs\envgenai\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Using cached rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\anaconda3\envs\envgenai\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\envs\envgenai\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\envs\envgenai\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\envs\envgenai\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\envs\envgenai\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\envs\envgenai\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (2.5.0)
# Downloading gradio-5.45.0-py3-none-any.whl (60.4 MB)
#    ---------------------------------------- 0.0/60.4 MB ? eta -:--:--
#     --------------------------------------- 0.8/60.4 MB 4.2 MB/s eta 0:00:15
#     --------------------------------------- 1.3/60.4 MB 3.5 MB/s eta 0:00:17
#    - -------------------------------------- 1.8/60.4 MB 3.4 MB/s eta 0:00:18
#    -- ------------------------------------- 3.1/60.4 MB 3.8 MB/s eta 0:00:15
#    -- ------------------------------------- 4.2/60.4 MB 4.1 MB/s eta 0:00:14
#    --- ------------------------------------ 5.0/60.4 MB 4.0 MB/s eta 0:00:14
#    --- ------------------------------------ 6.0/60.4 MB 4.1 MB/s eta 0:00:14
#    ---- ----------------------------------- 6.8/60.4 MB 4.2 MB/s eta 0:00:13
#    ----- ---------------------------------- 7.9/60.4 MB 4.2 MB/s eta 0:00:13
#    ----- ---------------------------------- 8.7/60.4 MB 4.1 MB/s eta 0:00:13
#    ------ --------------------------------- 9.7/60.4 MB 4.2 MB/s eta 0:00:13
#    ------ --------------------------------- 10.2/60.4 MB 4.2 MB/s eta 0:00:12
#    ------- -------------------------------- 11.3/60.4 MB 4.1 MB/s eta 0:00:12
#    -------- ------------------------------- 12.3/60.4 MB 4.1 MB/s eta 0:00:12
#    -------- ------------------------------- 13.4/60.4 MB 4.2 MB/s eta 0:00:12
#    --------- ------------------------------ 14.2/60.4 MB 4.2 MB/s eta 0:00:12
#    --------- ------------------------------ 14.9/60.4 MB 4.2 MB/s eta 0:00:11
#    ---------- ----------------------------- 16.0/60.4 MB 4.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 17.0/60.4 MB 4.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 18.1/60.4 MB 4.3 MB/s eta 0:00:10
#    ------------ --------------------------- 18.9/60.4 MB 4.3 MB/s eta 0:00:10
#    ------------ --------------------------- 19.4/60.4 MB 4.2 MB/s eta 0:00:10
#    ------------- -------------------------- 20.2/60.4 MB 4.1 MB/s eta 0:00:10
#    ------------- -------------------------- 21.0/60.4 MB 4.1 MB/s eta 0:00:10
#    -------------- ------------------------- 21.8/60.4 MB 4.1 MB/s eta 0:00:10
#    --------------- ------------------------ 22.8/60.4 MB 4.1 MB/s eta 0:00:10
#    --------------- ------------------------ 23.6/60.4 MB 4.1 MB/s eta 0:00:09
#    ---------------- ----------------------- 24.4/60.4 MB 4.1 MB/s eta 0:00:09
#    ---------------- ----------------------- 25.4/60.4 MB 4.1 MB/s eta 0:00:09
#    ----------------- ---------------------- 26.5/60.4 MB 4.1 MB/s eta 0:00:09
#    ------------------ --------------------- 27.3/60.4 MB 4.2 MB/s eta 0:00:08
#    ------------------ --------------------- 28.3/60.4 MB 4.2 MB/s eta 0:00:08
#    ------------------- -------------------- 28.8/60.4 MB 4.1 MB/s eta 0:00:08
#    ------------------- -------------------- 30.1/60.4 MB 4.2 MB/s eta 0:00:08
#    -------------------- ------------------- 31.2/60.4 MB 4.2 MB/s eta 0:00:07
#    --------------------- ------------------ 32.0/60.4 MB 4.2 MB/s eta 0:00:07
#    --------------------- ------------------ 32.8/60.4 MB 4.2 MB/s eta 0:00:07
#    ---------------------- ----------------- 33.8/60.4 MB 4.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 34.9/60.4 MB 4.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 35.9/60.4 MB 4.2 MB/s eta 0:00:06
#    ------------------------ --------------- 37.0/60.4 MB 4.2 MB/s eta 0:00:06
#    ------------------------- -------------- 37.7/60.4 MB 4.2 MB/s eta 0:00:06
#    ------------------------- -------------- 38.8/60.4 MB 4.2 MB/s eta 0:00:06
#    -------------------------- ------------- 39.8/60.4 MB 4.2 MB/s eta 0:00:05
#    --------------------------- ------------ 40.9/60.4 MB 4.3 MB/s eta 0:00:05
#    --------------------------- ------------ 41.9/60.4 MB 4.3 MB/s eta 0:00:05
#    ---------------------------- ----------- 43.3/60.4 MB 4.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 44.3/60.4 MB 4.3 MB/s eta 0:00:04
#    ------------------------------ --------- 45.4/60.4 MB 4.3 MB/s eta 0:00:04
#    ------------------------------ --------- 46.4/60.4 MB 4.3 MB/s eta 0:00:04
#    ------------------------------- -------- 47.7/60.4 MB 4.4 MB/s eta 0:00:03
#    -------------------------------- ------- 48.8/60.4 MB 4.4 MB/s eta 0:00:03
#    --------------------------------- ------ 49.8/60.4 MB 4.4 MB/s eta 0:00:03
#    --------------------------------- ------ 50.6/60.4 MB 4.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 51.9/60.4 MB 4.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 52.7/60.4 MB 4.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 54.3/60.4 MB 4.5 MB/s eta 0:00:02
#    ------------------------------------ --- 55.3/60.4 MB 4.5 MB/s eta 0:00:02
#    ------------------------------------- -- 56.4/60.4 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 57.7/60.4 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 58.7/60.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  59.8/60.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  60.3/60.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  60.3/60.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  60.3/60.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 60.4/60.4 MB 4.3 MB/s  0:00:14
# Downloading gradio_client-1.13.0-py3-none-any.whl (325 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached anyio-4.10.0-py3-none-any.whl (107 kB)
# Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading huggingface_hub-0.34.6-py3-none-any.whl (562 kB)
#    ---------------------------------------- 0.0/562.6 kB ? eta -:--:--
#    ---------------------------------------- 562.6/562.6 kB 2.1 MB/s  0:00:00
# Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl (131 kB)
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.47.3-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.17.4-py3-none-any.whl (46 kB)
# Using cached websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Downloading Brotli-1.1.0-cp311-cp311-win_amd64.whl (357 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading ruff-0.13.0-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.3 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/13.3 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 3.9 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/13.3 MB 4.0 MB/s eta 0:00:03
#    ------------ --------------------------- 4.2/13.3 MB 4.2 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/13.3 MB 4.3 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/13.3 MB 4.4 MB/s eta 0:00:02
#    --------------------- ------------------ 7.1/13.3 MB 4.5 MB/s eta 0:00:02
#    ------------------------ --------------- 8.1/13.3 MB 4.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.4/13.3 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 10.5/13.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.5/13.3 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.6/13.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 4.1 MB/s  0:00:03
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading ffmpy-0.6.1-py3-none-any.whl (5.5 kB)
# Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, brotli, websockets, tomlkit, sniffio, shellingham, semantic-version, ruff, python-multipart, orjson, h11, groovy, fsspec, filelock, ffmpy, click, aiofiles, uvicorn, rich, huggingface-hub, httpcore, anyio, typer, starlette, httpx, safehttpx, gradio-client, fastapi, gradio
#
#    ----------------------------------------  0/29 [pydub]
#    - --------------------------------------  1/29 [brotli]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    -- -------------------------------------  2/29 [websockets]
#    ---- -----------------------------------  3/29 [tomlkit]
#    ---- -----------------------------------  3/29 [tomlkit]
#    ----- ----------------------------------  4/29 [sniffio]
#    ------ ---------------------------------  5/29 [shellingham]
#    ------ ---------------------------------  5/29 [shellingham]
#    -------- -------------------------------  6/29 [semantic-version]
#    -------- -------------------------------  6/29 [semantic-version]
#    --------- ------------------------------  7/29 [ruff]
#    --------- ------------------------------  7/29 [ruff]
#    --------- ------------------------------  7/29 [ruff]
#    --------- ------------------------------  7/29 [ruff]
#    ----------- ----------------------------  8/29 [python-multipart]
#    ----------- ----------------------------  8/29 [python-multipart]
#    ------------ ---------------------------  9/29 [orjson]
#    ------------- -------------------------- 10/29 [h11]
#    --------------- ------------------------ 11/29 [groovy]
#    ---------------- ----------------------- 12/29 [fsspec]
#    ---------------- ----------------------- 12/29 [fsspec]
#    ---------------- ----------------------- 12/29 [fsspec]
#    ---------------- ----------------------- 12/29 [fsspec]
#    ---------------- ----------------------- 12/29 [fsspec]
#    ----------------- ---------------------- 13/29 [filelock]
#    ------------------- -------------------- 14/29 [ffmpy]
#    -------------------- ------------------- 15/29 [click]
#    -------------------- ------------------- 15/29 [click]
#    -------------------- ------------------- 15/29 [click]
#    ---------------------- ----------------- 16/29 [aiofiles]
#    ---------------------- ----------------- 16/29 [aiofiles]
#    ---------------------- ----------------- 16/29 [aiofiles]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ----------------------- ---------------- 17/29 [uvicorn]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    ------------------------ --------------- 18/29 [rich]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    -------------------------- ------------- 19/29 [huggingface-hub]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    --------------------------- ------------ 20/29 [httpcore]
#    ---------------------------- ----------- 21/29 [anyio]
#    ---------------------------- ----------- 21/29 [anyio]
#    ---------------------------- ----------- 21/29 [anyio]
#    ---------------------------- ----------- 21/29 [anyio]
#    ---------------------------- ----------- 21/29 [anyio]
#    ---------------------------- ----------- 21/29 [anyio]
#    ------------------------------ --------- 22/29 [typer]
#    ------------------------------ --------- 22/29 [typer]
#    ------------------------------ --------- 22/29 [typer]
#    ------------------------------- -------- 23/29 [starlette]
#    ------------------------------- -------- 23/29 [starlette]
#    ------------------------------- -------- 23/29 [starlette]
#    ------------------------------- -------- 23/29 [starlette]
#    ------------------------------- -------- 23/29 [starlette]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    ---------------------------------- ----- 25/29 [safehttpx]
#    ----------------------------------- ---- 26/29 [gradio-client]
#    ----------------------------------- ---- 26/29 [gradio-client]
#    ------------------------------------- -- 27/29 [fastapi]
#    ------------------------------------- -- 27/29 [fastapi]
#    ------------------------------------- -- 27/29 [fastapi]
#    ------------------------------------- -- 27/29 [fastapi]
#    ------------------------------------- -- 27/29 [fastapi]
#    ------------------------------------- -- 27/29 [fastapi]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    ---------------------------------------- 29/29 [gradio]
#
# Successfully installed aiofiles-24.1.0 anyio-4.10.0 brotli-1.1.0 click-8.2.1 fastapi-0.116.1 ffmpy-0.6.1 filelock-3.19.1 fsspec-2025.9.0 gradio-5.45.0 gradio-client-1.13.0 groovy-0.1.2 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.34.6 orjson-3.11.3 pydub-0.25.1 python-multipart-0.0.20 rich-14.1.0 ruff-0.13.0 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 sniffio-1.3.1 starlette-0.47.3 tomlkit-0.13.3 typer-0.17.4 uvicorn-0.35.0 websockets-15.0.1

# %%
import google.generativeai as genai
import gradio as gr

# Configure API key
genai.configure(api_key="AIzaSyBcJ1z5FQPOgE3-sY0w9O1xQJQhrYC4AvE")  # Replace with your actual Gemini API key

# Load the model
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# System message (used only for context)
system_msg = "You are a financial expert specializing in real estate investment and negotiation."

# Chatbot function
def CustomGemini(user_input):
    response = model.generate_content(system_msg + "\n" + user_input)
    return response.text  # Extract and return response

# Gradio Interface
"""
demo = gr.Interface(fn=CustomGemini, 
                    inputs="text", 
                    outputs="text", 
                    title="My Saving Assistant")
"""

demo = gr.Interface(
    fn=CustomGemini,
    inputs=gr.Textbox(label="Enter your prompt"),
    outputs=gr.Textbox(label="Output", lines=15),  # <-- multiline display
    title="My Saving Assistant"
)

# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
